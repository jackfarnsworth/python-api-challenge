# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import gmaps
from datetime import date
from scipy.stats import linregress
from pprint import pprint


# Import API key
from api_keys import weather_api_key, g_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
gmaps.configure(api_key=g_key)
# Out:
# 'YOUR KEY HERE!'

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 647

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
# set up lists to hold reponse info
response_info = [[],[],[],[],[],[]]
invalid_cities = []
# Loop through the list of cities and perform a request for data on each
i = 0
j = 1
for city in cities:
    i += 1
    response = requests.get(query_url + city).json()
    try:
        print(f"Processing Record {i} of set {j} | {city}")
        response_info[0].append(response['coord']['lon'])
        response_info[1].append(response['coord']['lat'])
        response_info[2].append(response['main']['temp_max'])
        response_info[3].append(response['main']['humidity'])
        response_info[4].append(response['clouds']['all'])
        response_info[5].append(response['wind']['speed'])
    except:
        print("City not found. Skipping...")
    if i >= 50:
        print("sleeping")
        i = 0;
        j += 1;
        time.sleep(60)
# Out:
# Processing Record 1 of set 1 | mersin
# Processing Record 2 of set 1 | busselton
# Processing Record 3 of set 1 | portland
# Processing Record 4 of set 1 | rikitea
# Processing Record 5 of set 1 | dzhusaly
# City not found. Skipping...
# Processing Record 6 of set 1 | qaanaaq
# Processing Record 7 of set 1 | darhan
# Processing Record 8 of set 1 | bengkulu
# Processing Record 9 of set 1 | hilo
# Processing Record 10 of set 1 | ushirombo
# Processing Record 11 of set 1 | amderma
# City not found. Skipping...
# Processing Record 12 of set 1 | kapaa
# Processing Record 13 of set 1 | mushie
# Processing Record 14 of set 1 | thompson
# Processing Record 15 of set 1 | vaitupu
# City not found. Skipping...
# Processing Record 16 of set 1 | dabola
# Processing Record 17 of set 1 | port elizabeth
# Processing Record 18 of set 1 | lakota
# Processing Record 19 of set 1 | ugra
# Processing Record 20 of set 1 | palmer
# Processing Record 21 of set 1 | punta arenas
# Processing Record 22 of set 1 | te anau
# Processing Record 23 of set 1 | atambua
# Processing Record 24 of set 1 | paamiut
# Processing Record 25 of set 1 | souillac
# Processing Record 26 of set 1 | belushya guba
# City not found. Skipping...
# Processing Record 27 of set 1 | ilulissat
# Processing Record 28 of set 1 | acajutla
# Processing Record 29 of set 1 | grand river south east
# City not found. Skipping...
# Processing Record 30 of set 1 | raquira
# Processing Record 31 of set 1 | mount gambier
# Processing Record 32 of set 1 | shubarshi
# Processing Record 33 of set 1 | ponta do sol
# Processing Record 34 of set 1 | floro
# Processing Record 35 of set 1 | port alfred
# Processing Record 36 of set 1 | norman wells
# Processing Record 37 of set 1 | lorengau
# Processing Record 38 of set 1 | berezovka
# Processing Record 39 of set 1 | kamenka
# Processing Record 40 of set 1 | cape town
# Processing Record 41 of set 1 | tuatapere
# Processing Record 42 of set 1 | geraldton
# Processing Record 43 of set 1 | marabba
# Processing Record 44 of set 1 | sitka
# Processing Record 45 of set 1 | henties bay
# Processing Record 46 of set 1 | buala
# Processing Record 47 of set 1 | saleaula
# City not found. Skipping...
# Processing Record 48 of set 1 | taolanaro
# City not found. Skipping...
# Processing Record 49 of set 1 | half moon bay
# Processing Record 50 of set 1 | bredasdorp
# sleeping
# Processing Record 1 of set 2 | juba
# Processing Record 2 of set 2 | ambon
# Processing Record 3 of set 2 | vaini
# Processing Record 4 of set 2 | pangnirtung
# Processing Record 5 of set 2 | kudahuvadhoo
# Processing Record 6 of set 2 | talnakh
# Processing Record 7 of set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of set 2 | florianopolis
# Processing Record 9 of set 2 | deputatskiy
# Processing Record 10 of set 2 | tasiilaq
# Processing Record 11 of set 2 | meyungs
# City not found. Skipping...
# Processing Record 12 of set 2 | khatanga
# Processing Record 13 of set 2 | albany
# Processing Record 14 of set 2 | lillooet
# Processing Record 15 of set 2 | pevek
# Processing Record 16 of set 2 | meulaboh
# Processing Record 17 of set 2 | padang
# Processing Record 18 of set 2 | dombas
# Processing Record 19 of set 2 | leningradskiy
# Processing Record 20 of set 2 | ilebo
# Processing Record 21 of set 2 | mutsamudu
# City not found. Skipping...
# Processing Record 22 of set 2 | ribeira grande
# Processing Record 23 of set 2 | puerto ayora
# Processing Record 24 of set 2 | inhambane
# Processing Record 25 of set 2 | liverpool
# Processing Record 26 of set 2 | hermanus
# Processing Record 27 of set 2 | erenhot
# Processing Record 28 of set 2 | clyde river
# Processing Record 29 of set 2 | yanam
# Processing Record 30 of set 2 | mataura
# Processing Record 31 of set 2 | ostrovnoy
# Processing Record 32 of set 2 | lebu
# Processing Record 33 of set 2 | talcahuano
# Processing Record 34 of set 2 | hobyo
# Processing Record 35 of set 2 | sault sainte marie
# Processing Record 36 of set 2 | omsukchan
# Processing Record 37 of set 2 | ye
# City not found. Skipping...
# Processing Record 38 of set 2 | dalianwan
# Processing Record 39 of set 2 | bethel
# Processing Record 40 of set 2 | atuona
# Processing Record 41 of set 2 | caruray
# Processing Record 42 of set 2 | avarua
# Processing Record 43 of set 2 | luderitz
# Processing Record 44 of set 2 | nicoya
# Processing Record 45 of set 2 | butaritari
# Processing Record 46 of set 2 | sistranda
# Processing Record 47 of set 2 | cabo san lucas
# Processing Record 48 of set 2 | lolua
# City not found. Skipping...
# Processing Record 49 of set 2 | tura
# Processing Record 50 of set 2 | amuntai
# sleeping
# Processing Record 1 of set 3 | sambava
# Processing Record 2 of set 3 | east london
# Processing Record 3 of set 3 | iqaluit
# Processing Record 4 of set 3 | broome
# Processing Record 5 of set 3 | alta floresta
# Processing Record 6 of set 3 | yulara
# Processing Record 7 of set 3 | poum
# Processing Record 8 of set 3 | gat
# Processing Record 9 of set 3 | ayacucho
# Processing Record 10 of set 3 | ushuaia
# Processing Record 11 of set 3 | georgetown
# Processing Record 12 of set 3 | carutapera
# Processing Record 13 of set 3 | krabi
# Processing Record 14 of set 3 | xichang
# Processing Record 15 of set 3 | marawi
# Processing Record 16 of set 3 | castro
# Processing Record 17 of set 3 | ust-nera
# Processing Record 18 of set 3 | price
# Processing Record 19 of set 3 | ngukurr
# City not found. Skipping...
# Processing Record 20 of set 3 | mayor pablo lagerenza
# Processing Record 21 of set 3 | kimbe
# Processing Record 22 of set 3 | comodoro rivadavia
# Processing Record 23 of set 3 | mitsamiouli
# Processing Record 24 of set 3 | kodiak
# Processing Record 25 of set 3 | bergen
# Processing Record 26 of set 3 | vanimo
# Processing Record 27 of set 3 | muros
# Processing Record 28 of set 3 | bluff
# Processing Record 29 of set 3 | roma
# Processing Record 30 of set 3 | hobart
# Processing Record 31 of set 3 | yellowknife
# Processing Record 32 of set 3 | amahai
# Processing Record 33 of set 3 | sur
# Processing Record 34 of set 3 | jambi
# Processing Record 35 of set 3 | lesnikovo
# Processing Record 36 of set 3 | fallon
# Processing Record 37 of set 3 | barawe
# City not found. Skipping...
# Processing Record 38 of set 3 | guerrero negro
# Processing Record 39 of set 3 | nikolskoye
# Processing Record 40 of set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of set 3 | kavieng
# Processing Record 42 of set 3 | krasnoselkup
# Processing Record 43 of set 3 | kununurra
# Processing Record 44 of set 3 | aranos
# Processing Record 45 of set 3 | ca mau
# Processing Record 46 of set 3 | saint-pierre
# Processing Record 47 of set 3 | chokurdakh
# Processing Record 48 of set 3 | tuktoyaktuk
# Processing Record 49 of set 3 | kahului
# Processing Record 50 of set 3 | saint-philippe
# sleeping
# Processing Record 1 of set 4 | katsuyama
# Processing Record 2 of set 4 | petropavlovsk-kamchatskiy
# Processing Record 3 of set 4 | sorland
# Processing Record 4 of set 4 | san cristobal
# Processing Record 5 of set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of set 4 | talara
# Processing Record 7 of set 4 | mayo
# Processing Record 8 of set 4 | sorvag
# City not found. Skipping...
# Processing Record 9 of set 4 | olkhovka
# Processing Record 10 of set 4 | ban nahin
# Processing Record 11 of set 4 | kruisfontein
# Processing Record 12 of set 4 | grindavik
# Processing Record 13 of set 4 | sonoita
# Processing Record 14 of set 4 | kemijarvi
# Processing Record 15 of set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of set 4 | tchaourou
# Processing Record 17 of set 4 | gilbues
# Processing Record 18 of set 4 | shellbrook
# Processing Record 19 of set 4 | tres arroyos
# Processing Record 20 of set 4 | guangyuan
# Processing Record 21 of set 4 | dikson
# Processing Record 22 of set 4 | bogandinskiy
# Processing Record 23 of set 4 | constitucion
# Processing Record 24 of set 4 | usinsk
# Processing Record 25 of set 4 | luzhou
# Processing Record 26 of set 4 | baruun-urt
# Processing Record 27 of set 4 | fortuna
# Processing Record 28 of set 4 | kendari
# Processing Record 29 of set 4 | rio gallegos
# Processing Record 30 of set 4 | kentau
# Processing Record 31 of set 4 | saint-georges
# Processing Record 32 of set 4 | port blair
# Processing Record 33 of set 4 | tabiauea
# City not found. Skipping...
# Processing Record 34 of set 4 | bandarbeyla
# Processing Record 35 of set 4 | tsihombe
# City not found. Skipping...
# Processing Record 36 of set 4 | san joaquin
# Processing Record 37 of set 4 | stornoway
# Processing Record 38 of set 4 | north bend
# Processing Record 39 of set 4 | zhoucheng
# Processing Record 40 of set 4 | sangar
# Processing Record 41 of set 4 | tigil
# Processing Record 42 of set 4 | nantucket
# Processing Record 43 of set 4 | manokwari
# Processing Record 44 of set 4 | nome
# Processing Record 45 of set 4 | kadoma
# Processing Record 46 of set 4 | samusu
# City not found. Skipping...
# Processing Record 47 of set 4 | vanavara
# Processing Record 48 of set 4 | tysmenychany
# Processing Record 49 of set 4 | oyama
# Processing Record 50 of set 4 | viedma
# sleeping
# Processing Record 1 of set 5 | lephepe
# City not found. Skipping...
# Processing Record 2 of set 5 | san jose
# Processing Record 3 of set 5 | rio branco
# Processing Record 4 of set 5 | zhangjiakou
# Processing Record 5 of set 5 | candawaga
# City not found. Skipping...
# Processing Record 6 of set 5 | new norfolk
# Processing Record 7 of set 5 | esperance
# Processing Record 8 of set 5 | paso de carrasco
# Processing Record 9 of set 5 | la asuncion
# Processing Record 10 of set 5 | saskylakh
# Processing Record 11 of set 5 | maghama
# City not found. Skipping...
# Processing Record 12 of set 5 | liepaja
# Processing Record 13 of set 5 | tondano
# Processing Record 14 of set 5 | quatre cocos
# Processing Record 15 of set 5 | hofn
# Processing Record 16 of set 5 | honavar
# Processing Record 17 of set 5 | takoradi
# Processing Record 18 of set 5 | flin flon
# Processing Record 19 of set 5 | harper
# Processing Record 20 of set 5 | khorramabad
# Processing Record 21 of set 5 | barentsburg
# City not found. Skipping...
# Processing Record 22 of set 5 | mar del plata
# Processing Record 23 of set 5 | san-pedro
# Processing Record 24 of set 5 | ginda
# Processing Record 25 of set 5 | sao joao da barra
# Processing Record 26 of set 5 | rosarito
# Processing Record 27 of set 5 | victoria
# Processing Record 28 of set 5 | namibe
# Processing Record 29 of set 5 | esna
# Processing Record 30 of set 5 | baykit
# Processing Record 31 of set 5 | santa isabel
# Processing Record 32 of set 5 | billings
# Processing Record 33 of set 5 | lazaro cardenas
# Processing Record 34 of set 5 | los llanos de aridane
# Processing Record 35 of set 5 | champerico
# Processing Record 36 of set 5 | katsuura
# Processing Record 37 of set 5 | jalu
# Processing Record 38 of set 5 | pingzhuang
# Processing Record 39 of set 5 | lafia
# Processing Record 40 of set 5 | nanortalik
# Processing Record 41 of set 5 | chiredzi
# Processing Record 42 of set 5 | airai
# Processing Record 43 of set 5 | jamestown
# Processing Record 44 of set 5 | santa fe
# Processing Record 45 of set 5 | bandrele
# Processing Record 46 of set 5 | calbuco
# Processing Record 47 of set 5 | gamba
# Processing Record 48 of set 5 | aklavik
# Processing Record 49 of set 5 | faanui
# Processing Record 50 of set 5 | mahebourg
# sleeping
# Processing Record 1 of set 6 | hithadhoo
# Processing Record 2 of set 6 | clyde
# Processing Record 3 of set 6 | toliary
# City not found. Skipping...
# Processing Record 4 of set 6 | abu samrah
# Processing Record 5 of set 6 | filingue
# Processing Record 6 of set 6 | rokytne
# Processing Record 7 of set 6 | kaitangata
# Processing Record 8 of set 6 | gillette
# Processing Record 9 of set 6 | mascota
# Processing Record 10 of set 6 | porto nacional
# Processing Record 11 of set 6 | oranjemund
# Processing Record 12 of set 6 | mullaitivu
# City not found. Skipping...
# Processing Record 13 of set 6 | tilichiki
# Processing Record 14 of set 6 | wilmington island
# Processing Record 15 of set 6 | tomesti
# Processing Record 16 of set 6 | wuwei
# Processing Record 17 of set 6 | marzuq
# Processing Record 18 of set 6 | carnarvon
# Processing Record 19 of set 6 | kizukuri
# Processing Record 20 of set 6 | exmouth
# Processing Record 21 of set 6 | westport
# Processing Record 22 of set 6 | lagoa
# Processing Record 23 of set 6 | ladario
# Processing Record 24 of set 6 | krasnyy chikoy
# Processing Record 25 of set 6 | cherskiy
# Processing Record 26 of set 6 | saryshagan
# City not found. Skipping...
# Processing Record 27 of set 6 | virginia beach
# Processing Record 28 of set 6 | cabinda
# Processing Record 29 of set 6 | vila
# Processing Record 30 of set 6 | egvekinot
# Processing Record 31 of set 6 | new baltimore
# Processing Record 32 of set 6 | kongolo
# Processing Record 33 of set 6 | naze
# Processing Record 34 of set 6 | poya
# Processing Record 35 of set 6 | provideniya
# Processing Record 36 of set 6 | middelburg
# Processing Record 37 of set 6 | bathsheba
# Processing Record 38 of set 6 | zhangzhou
# Processing Record 39 of set 6 | hovd
# Processing Record 40 of set 6 | chuy
# Processing Record 41 of set 6 | octeville
# Processing Record 42 of set 6 | maniitsoq
# Processing Record 43 of set 6 | san patricio
# Processing Record 44 of set 6 | biella
# Processing Record 45 of set 6 | wakkanai
# Processing Record 46 of set 6 | dolzhanskaya
# Processing Record 47 of set 6 | rocha
# Processing Record 48 of set 6 | sabzevar
# Processing Record 49 of set 6 | beoumi
# Processing Record 50 of set 6 | kokstad
# sleeping
# Processing Record 1 of set 7 | hirado
# Processing Record 2 of set 7 | nador
# Processing Record 3 of set 7 | saldanha
# Processing Record 4 of set 7 | codrington
# Processing Record 5 of set 7 | kommunisticheskiy
# Processing Record 6 of set 7 | garowe
# Processing Record 7 of set 7 | bredy
# Processing Record 8 of set 7 | bambous virieux
# Processing Record 9 of set 7 | turan
# Processing Record 10 of set 7 | hasaki
# Processing Record 11 of set 7 | mandera
# Processing Record 12 of set 7 | basco
# Processing Record 13 of set 7 | seoul
# Processing Record 14 of set 7 | marathon
# Processing Record 15 of set 7 | porto walter
# Processing Record 16 of set 7 | vila franca do campo
# Processing Record 17 of set 7 | touros
# Processing Record 18 of set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of set 7 | faya
# Processing Record 20 of set 7 | kavaratti
# Processing Record 21 of set 7 | barra do corda
# Processing Record 22 of set 7 | coahuayana
# Processing Record 23 of set 7 | chagda
# City not found. Skipping...
# Processing Record 24 of set 7 | barrow
# Processing Record 25 of set 7 | kailahun
# Processing Record 26 of set 7 | port-gentil
# Processing Record 27 of set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 28 of set 7 | aden
# Processing Record 29 of set 7 | kutum
# Processing Record 30 of set 7 | high level
# Processing Record 31 of set 7 | flinders
# Processing Record 32 of set 7 | ambilobe
# Processing Record 33 of set 7 | longyearbyen
# Processing Record 34 of set 7 | masuguru
# Processing Record 35 of set 7 | changqing
# Processing Record 36 of set 7 | peniche
# Processing Record 37 of set 7 | kadykchan
# City not found. Skipping...
# Processing Record 38 of set 7 | miranda
# Processing Record 39 of set 7 | tarut
# Processing Record 40 of set 7 | turukhansk
# Processing Record 41 of set 7 | mrakovo
# Processing Record 42 of set 7 | nelson
# Processing Record 43 of set 7 | progreso
# Processing Record 44 of set 7 | kawalu
# Processing Record 45 of set 7 | lewiston
# Processing Record 46 of set 7 | severo-kurilsk
# Processing Record 47 of set 7 | naron
# Processing Record 48 of set 7 | vao
# Processing Record 49 of set 7 | palo alto
# Processing Record 50 of set 7 | mackay
# sleeping
# Processing Record 1 of set 8 | san clemente
# Processing Record 2 of set 8 | bunia
# Processing Record 3 of set 8 | eureka
# Processing Record 4 of set 8 | pitimbu
# Processing Record 5 of set 8 | vestmanna
# Processing Record 6 of set 8 | alofi
# Processing Record 7 of set 8 | linxia
# Processing Record 8 of set 8 | benguela
# Processing Record 9 of set 8 | luena
# Processing Record 10 of set 8 | olafsvik
# Processing Record 11 of set 8 | gambiran
# Processing Record 12 of set 8 | dekar
# Processing Record 13 of set 8 | tomatlan
# Processing Record 14 of set 8 | neuquen
# Processing Record 15 of set 8 | angoche
# Processing Record 16 of set 8 | san luis de la paz
# Processing Record 17 of set 8 | upernavik
# Processing Record 18 of set 8 | kumano
# Processing Record 19 of set 8 | iki-burul
# Processing Record 20 of set 8 | ixtapa
# Processing Record 21 of set 8 | kyra
# Processing Record 22 of set 8 | yarmouth
# Processing Record 23 of set 8 | montlucon
# Processing Record 24 of set 8 | goya
# Processing Record 25 of set 8 | ewa beach
# Processing Record 26 of set 8 | suzu
# City not found. Skipping...
# Processing Record 27 of set 8 | mount vernon
# Processing Record 28 of set 8 | barbar
# City not found. Skipping...
# Processing Record 29 of set 8 | sao filipe
# Processing Record 30 of set 8 | chapais
# Processing Record 31 of set 8 | sayanskiy
# City not found. Skipping...
# Processing Record 32 of set 8 | morros
# Processing Record 33 of set 8 | cidreira
# Processing Record 34 of set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 35 of set 8 | daru
# Processing Record 36 of set 8 | kieta
# Processing Record 37 of set 8 | coihaique
# Processing Record 38 of set 8 | lumphat
# Processing Record 39 of set 8 | bonfim
# Processing Record 40 of set 8 | nishihara
# Processing Record 41 of set 8 | coquimbo
# Processing Record 42 of set 8 | agadez
# Processing Record 43 of set 8 | marcona
# City not found. Skipping...
# Processing Record 44 of set 8 | george
# Processing Record 45 of set 8 | konskie
# Processing Record 46 of set 8 | todos santos
# Processing Record 47 of set 8 | yaan
# Processing Record 48 of set 8 | makat
# Processing Record 49 of set 8 | quesnel
# Processing Record 50 of set 8 | nuuk
# sleeping
# Processing Record 1 of set 9 | atar
# Processing Record 2 of set 9 | tupik
# Processing Record 3 of set 9 | kpandae
# Processing Record 4 of set 9 | bosconia
# Processing Record 5 of set 9 | yablonovo
# Processing Record 6 of set 9 | ugoofaaru
# Processing Record 7 of set 9 | maxixe
# Processing Record 8 of set 9 | guayaramerin
# Processing Record 9 of set 9 | oistins
# Processing Record 10 of set 9 | hamilton
# Processing Record 11 of set 9 | road town
# Processing Record 12 of set 9 | pangai
# Processing Record 13 of set 9 | fort saint james
# Processing Record 14 of set 9 | svetlogorsk
# Processing Record 15 of set 9 | verkhoyansk
# Processing Record 16 of set 9 | arroyos y esteros
# Processing Record 17 of set 9 | torbay
# Processing Record 18 of set 9 | koslan
# Processing Record 19 of set 9 | chumikan
# Processing Record 20 of set 9 | santa isabel do rio negro
# Processing Record 21 of set 9 | belmonte
# Processing Record 22 of set 9 | adrar
# Processing Record 23 of set 9 | college
# Processing Record 24 of set 9 | yangjiang
# Processing Record 25 of set 9 | karaul
# City not found. Skipping...
# Processing Record 26 of set 9 | luwuk
# Processing Record 27 of set 9 | petropavlovka
# Processing Record 28 of set 9 | chulman
# Processing Record 29 of set 9 | norden
# Processing Record 30 of set 9 | nerja
# Processing Record 31 of set 9 | ardesen
# Processing Record 32 of set 9 | kangaatsiaq
# Processing Record 33 of set 9 | shingu
# Processing Record 34 of set 9 | bosansko grahovo
# Processing Record 35 of set 9 | gorin
# Processing Record 36 of set 9 | antalaha
# Processing Record 37 of set 9 | jimma
# Processing Record 38 of set 9 | sinkat
# City not found. Skipping...
# Processing Record 39 of set 9 | mombaca
# Processing Record 40 of set 9 | la ronge
# Processing Record 41 of set 9 | cockburn town
# Processing Record 42 of set 9 | udachnyy
# Processing Record 43 of set 9 | marica
# Processing Record 44 of set 9 | jaisalmer
# Processing Record 45 of set 9 | keshan
# City not found. Skipping...
# Processing Record 46 of set 9 | samarai
# Processing Record 47 of set 9 | tefe
# Processing Record 48 of set 9 | aksu
# Processing Record 49 of set 9 | salvacion
# Processing Record 50 of set 9 | ishigaki
# sleeping
# Processing Record 1 of set 10 | dingle
# Processing Record 2 of set 10 | kenora
# Processing Record 3 of set 10 | kharan
# Processing Record 4 of set 10 | mabaruma
# Processing Record 5 of set 10 | jieshi
# Processing Record 6 of set 10 | makakilo city
# Processing Record 7 of set 10 | sioux lookout
# Processing Record 8 of set 10 | nieuw amsterdam
# Processing Record 9 of set 10 | cayenne
# Processing Record 10 of set 10 | beloha
# Processing Record 11 of set 10 | torres novas
# Processing Record 12 of set 10 | inuvik
# Processing Record 13 of set 10 | cortes
# Processing Record 14 of set 10 | auki
# Processing Record 15 of set 10 | moree
# Processing Record 16 of set 10 | zaysan
# Processing Record 17 of set 10 | port hueneme
# Processing Record 18 of set 10 | narsaq
# Processing Record 19 of set 10 | sandnessjoen
# Processing Record 20 of set 10 | berlevag
# Processing Record 21 of set 10 | luau
# Processing Record 22 of set 10 | kadoshkino
# Processing Record 23 of set 10 | cotonou
# Processing Record 24 of set 10 | khonuu
# City not found. Skipping...
# Processing Record 25 of set 10 | lambarene
# Processing Record 26 of set 10 | shelburne
# Processing Record 27 of set 10 | karakulino
# Processing Record 28 of set 10 | changli
# Processing Record 29 of set 10 | pavelets
# Processing Record 30 of set 10 | lewistown
# Processing Record 31 of set 10 | ternate
# Processing Record 32 of set 10 | yangcun
# Processing Record 33 of set 10 | kenai
# Processing Record 34 of set 10 | vitim
# Processing Record 35 of set 10 | dindori
# Processing Record 36 of set 10 | aykhal
# Processing Record 37 of set 10 | port lincoln
# Processing Record 38 of set 10 | xuddur
# Processing Record 39 of set 10 | alugan
# Processing Record 40 of set 10 | grand gaube
# Processing Record 41 of set 10 | minab
# Processing Record 42 of set 10 | anadyr
# Processing Record 43 of set 10 | tete
# Processing Record 44 of set 10 | oyek
# Processing Record 45 of set 10 | nouadhibou
# Processing Record 46 of set 10 | balud
# Processing Record 47 of set 10 | lumajang
# Processing Record 48 of set 10 | mashhad
# Processing Record 49 of set 10 | gravdal
# Processing Record 50 of set 10 | tadine
# sleeping
# Processing Record 1 of set 11 | sibu
# Processing Record 2 of set 11 | lielvarde
# Processing Record 3 of set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 4 of set 11 | sa kaeo
# Processing Record 5 of set 11 | doha
# Processing Record 6 of set 11 | skjervoy
# Processing Record 7 of set 11 | ajmer
# Processing Record 8 of set 11 | san quintin
# Processing Record 9 of set 11 | tautira
# Processing Record 10 of set 11 | klaksvik
# Processing Record 11 of set 11 | thinadhoo
# Processing Record 12 of set 11 | soe
# Processing Record 13 of set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 14 of set 11 | mrirt
# City not found. Skipping...
# Processing Record 15 of set 11 | malwan
# City not found. Skipping...
# Processing Record 16 of set 11 | lata
# Processing Record 17 of set 11 | adana
# Processing Record 18 of set 11 | korla
# Processing Record 19 of set 11 | biak
# Processing Record 20 of set 11 | turayf
# Processing Record 21 of set 11 | miraflores
# Processing Record 22 of set 11 | marv dasht
# City not found. Skipping...
# Processing Record 23 of set 11 | vila velha
# Processing Record 24 of set 11 | yunjinghong
# City not found. Skipping...
# Processing Record 25 of set 11 | puerto escondido
# Processing Record 26 of set 11 | nguiu
# City not found. Skipping...
# Processing Record 27 of set 11 | yumen
# Processing Record 28 of set 11 | arraial do cabo
# Processing Record 29 of set 11 | duz
# City not found. Skipping...
# Processing Record 30 of set 11 | chikoy
# City not found. Skipping...
# Processing Record 31 of set 11 | sal rei
# Processing Record 32 of set 11 | yilan
# Processing Record 33 of set 11 | tahe
# Processing Record 34 of set 11 | marsh harbour
# Processing Record 35 of set 11 | valparaiso
# Processing Record 36 of set 11 | saint george
# Processing Record 37 of set 11 | puerto colombia
# Processing Record 38 of set 11 | kupang
# Processing Record 39 of set 11 | along
# Processing Record 40 of set 11 | husavik
# Processing Record 41 of set 11 | dalvik
# Processing Record 42 of set 11 | northam
# Processing Record 43 of set 11 | bilibino
# Processing Record 44 of set 11 | marovoay
# Processing Record 45 of set 11 | show low
# Processing Record 46 of set 11 | vallenar
# Processing Record 47 of set 11 | anyang
# Processing Record 48 of set 11 | buenos aires
# Processing Record 49 of set 11 | sibolga
# Processing Record 50 of set 11 | ibra
# sleeping
# Processing Record 1 of set 12 | taltal
# Processing Record 2 of set 12 | cam ranh
# Processing Record 3 of set 12 | gondar
# Processing Record 4 of set 12 | praia da vitoria
# Processing Record 5 of set 12 | yakeshi
# Processing Record 6 of set 12 | pangody
# Processing Record 7 of set 12 | muisne
# Processing Record 8 of set 12 | mocuba
# Processing Record 9 of set 12 | challapata
# Processing Record 10 of set 12 | russell
# Processing Record 11 of set 12 | belle glade
# Processing Record 12 of set 12 | owando
# Processing Record 13 of set 12 | halalo
# City not found. Skipping...
# Processing Record 14 of set 12 | armidale
# Processing Record 15 of set 12 | kobojango
# City not found. Skipping...
# Processing Record 16 of set 12 | svobodnyy
# Processing Record 17 of set 12 | soyo
# Processing Record 18 of set 12 | ayia marina
# Processing Record 19 of set 12 | kharp
# Processing Record 20 of set 12 | fairbanks
# Processing Record 21 of set 12 | tiksi
# Processing Record 22 of set 12 | dauphin
# Processing Record 23 of set 12 | seymchan
# Processing Record 24 of set 12 | vardo
# Processing Record 25 of set 12 | tarauaca
# Processing Record 26 of set 12 | zhigansk
# Processing Record 27 of set 12 | islamkot
# Processing Record 28 of set 12 | ciempozuelos
# Processing Record 29 of set 12 | mana
# Processing Record 30 of set 12 | belaya gora
# Processing Record 31 of set 12 | kurilsk
# Processing Record 32 of set 12 | srednekolymsk
# Processing Record 33 of set 12 | kedrovyy
# Processing Record 34 of set 12 | lakhnadon
# Processing Record 35 of set 12 | brasilia
# Processing Record 36 of set 12 | vaitape
# Processing Record 37 of set 12 | mogzon
# Processing Record 38 of set 12 | saint anthony
# Processing Record 39 of set 12 | ndele
# Processing Record 40 of set 12 | burica
# City not found. Skipping...
# Processing Record 41 of set 12 | andenes
# Processing Record 42 of set 12 | hansi
# Processing Record 43 of set 12 | bainbridge
# Processing Record 44 of set 12 | volosovo
# Processing Record 45 of set 12 | kalianget
# Processing Record 46 of set 12 | bulungu
# Processing Record 47 of set 12 | banepa
# Processing Record 48 of set 12 | marshall
# Processing Record 49 of set 12 | tawkar
# City not found. Skipping...
# Processing Record 50 of set 12 | kamenskoye
# City not found. Skipping...
# sleeping
# Processing Record 1 of set 13 | vilhena
# Processing Record 2 of set 13 | hermiston
# Processing Record 3 of set 13 | rudbar
# Processing Record 4 of set 13 | sesheke
# Processing Record 5 of set 13 | sloboda
# Processing Record 6 of set 13 | andros
# Processing Record 7 of set 13 | omaruru
# Processing Record 8 of set 13 | ozernovskiy
# Processing Record 9 of set 13 | necochea
# Processing Record 10 of set 13 | urucara
# Processing Record 11 of set 13 | hvammstangi
# City not found. Skipping...
# Processing Record 12 of set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 13 of set 13 | miri
# Processing Record 14 of set 13 | karratha
# Processing Record 15 of set 13 | forest grove
# Processing Record 16 of set 13 | carthage
# Processing Record 17 of set 13 | ghanzi
# Processing Record 18 of set 13 | ekhabi
# Processing Record 19 of set 13 | bougouni
# Processing Record 20 of set 13 | tosya
# Processing Record 21 of set 13 | leh
# Processing Record 22 of set 13 | ulaangom
# Processing Record 23 of set 13 | badaojiang
# City not found. Skipping...
# Processing Record 24 of set 13 | gashua
# Processing Record 25 of set 13 | launceston
# Processing Record 26 of set 13 | salym
# Processing Record 27 of set 13 | southbridge
# Processing Record 28 of set 13 | waipawa
# Processing Record 29 of set 13 | porto belo
# Processing Record 30 of set 13 | ancud
# Processing Record 31 of set 13 | mwanza
# Processing Record 32 of set 13 | monrovia
# Processing Record 33 of set 13 | lucapa
# Processing Record 34 of set 13 | capaci
# Processing Record 35 of set 13 | phan rang
# City not found. Skipping...
# Processing Record 36 of set 13 | tabou
# Processing Record 37 of set 13 | kautokeino
# Processing Record 38 of set 13 | gizo
# Processing Record 39 of set 13 | babanusah
# City not found. Skipping...
# Processing Record 40 of set 13 | yining
# Processing Record 41 of set 13 | lahat
# Processing Record 42 of set 13 | puerto princesa
# Processing Record 43 of set 13 | sauda
# Processing Record 44 of set 13 | pacifica
# Processing Record 45 of set 13 | nikolo-pavlovskoye
# Processing Record 46 of set 13 | friockheim
# Processing Record 47 of set 13 | zinder

# %%
df = pd.DataFrame(list(zip(cities, *response_info)), \
                        columns = ['City', 'Longitude', 'Latitude', 'Max Temperature', 'Humidity', 'Cloudiness', 'Wind Speed']) \
                        .set_index('City')
df.to_csv('city_weather.csv')

# %%
df
# Out:
#            Longitude  Latitude  Max Temperature  Humidity  Cloudiness  \
# City
# mersin       34.6509   36.8620            43.95        62          95
# busselton   115.3333  -33.6500            76.05        34           0
# portland   -122.6762   45.5234            41.77        74          20
# rikitea    -134.9692  -23.1203            78.22        79           4
# dzhusaly    -69.3632   77.4840            -8.34        59          73
# ...              ...       ...              ...       ...         ...
# kedrovyy      6.3542   59.6506            45.68        98         100
# lakhnadon  -122.4869   37.6138            57.11        76           0
# brasilia     60.0578   57.7831            11.41        90          98
# vaitape      -2.6636   56.6378            46.67        64          51
# mogzon        8.9881   13.8072            56.12        24           0
#
#            Wind Speed
# City
# mersin           7.07
# busselton        4.74
# portland         1.01
# rikitea         18.07
# dzhusaly         9.33
# ...               ...
# kedrovyy        10.56
# lakhnadon        1.01
# brasilia         6.91
# vaitape         18.77
# mogzon          13.76
#
# [587 rows x 6 columns]

# %%
x=df['Latitude']
y=df['Max Temperature']
plt.title(f"City Latitude vs Temperature ({date.today()})")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.scatter(x,y)
plt.show()

# %%
x=df['Latitude']
y=df['Humidity']
plt.title(f"City Latitude vs Humidity ({date.today()})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.scatter(x,y)
plt.show()

# %%
x=df['Latitude']
y=df['Cloudiness']
plt.title(f"City Latitude vs Clodiness ({date.today()})")
plt.xlabel("Latitude")
plt.ylabel("Cloud Cover (%)")
plt.scatter(x,y)
plt.show()

# %%
x=df['Latitude']
y=df['Wind Speed']
plt.title(f"City Latitude vs Wind Speed ({date.today()})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.scatter(x,y)
plt.show()

# %%
neglat = df.loc[df['Latitude'] < 0]
poslat = df.loc[df['Latitude'] >= 0]
x1, y1 = neglat['Latitude'], neglat['Max Temperature']
x2, y2 = poslat['Latitude'], poslat['Max Temperature']
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(15,7) )
slope1, intercept1, rvalue1, pvalue1, stderr1 = linregress(x1,y1)
slope2, intercept2, rvalue2, pvalue2, stderr2 = linregress(x2,y2)
ax1.scatter(x1,y1)
ax1.plot(x1, slope1 * x1 + intercept1, color = 'r')
ax2.scatter(x2,y2)
ax2.plot(x2, slope2 * x2 + intercept2, color = 'r')
fig.suptitle(f"Linear Regression of Latitude vs Temperature ({date.today()})")
# Out:
# Text(0.5, 0.98, 'Linear Regression of Latitude vs Temperature (2022-01-26)')

# %%
x1, y1 = neglat['Latitude'], neglat['Humidity']
x2, y2 = poslat['Latitude'], poslat['Humidity']
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(15,7) )
slope1, intercept1, rvalue1, pvalue1, stderr1 = linregress(x1,y1)
slope2, intercept2, rvalue2, pvalue2, stderr2 = linregress(x2,y2)
ax1.scatter(x1,y1)
ax1.plot(x1, slope1 * x1 + intercept1, color = 'r')
ax2.scatter(x2,y2)
ax2.plot(x2, slope2 * x2 + intercept2, color = 'r')
fig.suptitle(f"Linear Regression of Latitude vs Humidity ({date.today()})")
# Out:
# Text(0.5, 0.98, 'Linear Regression of Latitude vs Humidity (2022-01-26)')

# %%
x1, y1 = neglat['Latitude'], neglat['Cloudiness']
x2, y2 = poslat['Latitude'], poslat['Cloudiness']
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(15,7) )
slope1, intercept1, rvalue1, pvalue1, stderr1 = linregress(x1,y1)
slope2, intercept2, rvalue2, pvalue2, stderr2 = linregress(x2,y2)
ax1.scatter(x1,y1)
ax1.plot(x1, slope1 * x1 + intercept1, color = 'r')
ax2.scatter(x2,y2)
ax2.plot(x2, slope2 * x2 + intercept2, color = 'r')
fig.suptitle(f"Linear Regression of Latitude vs Cloud Cover ({date.today()})")
# Out:
# Text(0.5, 0.98, 'Linear Regression of Latitude vs Cloud Cover (2022-01-26)')

# %%
x1, y1 = neglat['Latitude'], neglat['Wind Speed']
x2, y2 = poslat['Latitude'], poslat['Wind Speed']
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(15,7) )
slope1, intercept1, rvalue1, pvalue1, stderr1 = linregress(x1,y1)
slope2, intercept2, rvalue2, pvalue2, stderr2 = linregress(x2,y2)
ax1.scatter(x1,y1)
ax1.plot(x1, slope1 * x1 + intercept1, color = 'r')
ax2.scatter(x2,y2)
ax2.plot(x2, slope2 * x2 + intercept2, color = 'r')
fig.suptitle(f"Linear Regression of Latitude vs Wind Speed ({date.today()})")
# Out:
# Text(0.5, 0.98, 'Linear Regression of Latitude vs Wind Speed (2022-01-26)')

# %%
locs = df[["Latitude", "Longitude"]]
humidity = df["Humidity"]
fig = gmaps.figure()
heat_layer = gmaps.heatmap_layer(locs, weights=humidity, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=1)
fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
